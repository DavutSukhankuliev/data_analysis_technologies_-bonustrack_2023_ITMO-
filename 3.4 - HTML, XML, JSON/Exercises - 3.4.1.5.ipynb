# %% [markdown]
# 1. Дан некий фрагмент XML-документа:
# ```
# xml = """
# <?xml version="1.0" encoding="UTF-8"?>
# <Ads formatVersion="3" target="Avito.ru">
#     <Ad>
#         <Id>xjfdge4735202</Id>
#         <Category>Квартиры</Category>
#         <OperationType>Продам</OperationType>
#         <DateBegin>2015-11-27</DateBegin>
#         <DateEnd>2079-08-28</DateEnd>
#         <Description>
#             Новая, просторная, светлая и уютная квартира
#         </Description>
#         <ManagerName>Иван Петров-Водкин</ManagerName>
#         <ContactPhone>+7 916 683-78-22</ContactPhone>
#         <Images>
#             <Image url="http://img.test.ru/8F7B-4A4F3A0F2BA1.jpg" />
#         </Images>
#         <Rooms>2</Rooms>
#         <Square>61</Square>
#         <Floor>13</Floor>
#         <Floors>16</Floors>
#         <HouseType>Деревянный</HouseType>
#         <MarketType>Новостройка</MarketType>
#     </Ad>
#     <Ad>
#         <Id>xjfdge4735204</Id>
#         <Category>Комнаты</Category>
#         <Description>Новая, просторная, светлая и уютная квартира. </Description>
#         <Price>102000</Price>
#         <Rooms>2</Rooms>
#         <Square>61.3</Square>
#         <Floor>14</Floor>
#         <Floors>16</Floors>
#         <HouseType>Деревянный</HouseType>
#         <OperationType>Сдам</OperationType>
#     </Ad>
#     <Ad>
#         <Id>xjfdge4735205</Id>
#         <Category>Коммерческая недвижимость</Category>
#         <OperationType>Сдам</OperationType>
#         <Description>Hедвижимость.</Description>
#         <Price>12000</Price>
#         <Square>234</Square>
#     </Ad>
# </Ads>
# """
# ```
# При помощи языка Python напишите строку кода для получения всех тегов Description из приведенного выше XML-документа.
# ```
# from bs4 import BeautifulSoup
# xml_data = BeautifulSoup(xml, features='lxml')
# #ваш код здесь
# ```

# %%
from bs4 import BeautifulSoup

xml = """
<?xml version="1.0" encoding="UTF-8"?>
<Ads formatVersion="3" target="Avito.ru">
    <Ad>
        <Id>xjfdge4735202</Id>
        <Category>Квартиры</Category>
        <OperationType>Продам</OperationType>
        <DateBegin>2015-11-27</DateBegin>
        <DateEnd>2079-08-28</DateEnd>
        <Description>
            Новая, просторная, светлая и уютная квартира
        </Description>
        <ManagerName>Иван Петров-Водкин</ManagerName>
        <ContactPhone>+7 916 683-78-22</ContactPhone>
        <Images>
            <Image url="http://img.test.ru/8F7B-4A4F3A0F2BA1.jpg" />
        </Images>
        <Rooms>2</Rooms>
        <Square>61</Square>
        <Floor>13</Floor>
        <Floors>16</Floors>
        <HouseType>Деревянный</HouseType>
        <MarketType>Новостройка</MarketType>
    </Ad>
    <Ad>
        <Id>xjfdge4735204</Id>
        <Category>Комнаты</Category>
        <Description>Новая, просторная, светлая и уютная квартира. </Description>
        <Price>102000</Price>
        <Rooms>2</Rooms>
        <Square>61.3</Square>
        <Floor>14</Floor>
        <Floors>16</Floors>
        <HouseType>Деревянный</HouseType>
        <OperationType>Сдам</OperationType>
    </Ad>
    <Ad>
        <Id>xjfdge4735205</Id>
        <Category>Коммерческая недвижимость</Category>
        <OperationType>Сдам</OperationType>
        <Description>Hедвижимость.</Description>
        <Price>12000</Price>
        <Square>234</Square>
    </Ad>
</Ads>
"""

# Создание объекта BeautifulSoup и парсинг XML
xml_data = BeautifulSoup(xml, features='html.parser')

# Получение всех тегов <Description>
descriptions = xml_data.find_all('description')

# Печать текста каждого найденного тега <Description>
for description in descriptions:
    print(description.get_text(strip=True))
# Out:
# Новая, просторная, светлая и уютная квартира
# Новая, просторная, светлая и уютная квартира.
# Hедвижимость.

# %% [markdown]
# 2. Дан некий фрагмент XML-документа:
# ```
# xml = """
# <?xml version="1.0" encoding="UTF-8"?>
# <Ads formatVersion="3" target="Avito.ru">
#     <Ad>
#         <Id>xjfdge4735202</Id>
#         <Category>Квартиры</Category>
#         <OperationType>Продам</OperationType>
#         <DateBegin>2015-11-27</DateBegin>
#         <DateEnd>2079-08-28</DateEnd>
#         <Description>
#             Новая, просторная, светлая и уютная квартира
#         </Description>
#         <ManagerName>Иван Петров-Водкин</ManagerName>
#         <ContactPhone>+7 916 683-78-22</ContactPhone>
#         <Images>
#             <Image url="http://img.test.ru/8F7B-4A4F3A0F2BA1.jpg" />
#         </Images>
#         <Rooms>2</Rooms>
#         <Square>61</Square>
#         <Floor>13</Floor>
#         <Floors>16</Floors>
#         <HouseType>Деревянный</HouseType>
#         <MarketType>Новостройка</MarketType>
#     </Ad>
#     <Ad>
#         <Id>xjfdge4735204</Id>
#         <Category>Комнаты</Category>
#         <Description>Новая, просторная, светлая и уютная квартира. </Description>
#         <Price>102000</Price>
#         <Rooms>2</Rooms>
#         <Square>61.3</Square>
#         <Floor>14</Floor>
#         <Floors>16</Floors>
#         <HouseType>Деревянный</HouseType>
#         <OperationType>Сдам</OperationType>
#     </Ad>
#     <Ad>
#         <Id>xjfdge4735205</Id>
#         <Category>Коммерческая недвижимость</Category>
#         <OperationType>Сдам</OperationType>
#         <Description>Hедвижимость.</Description>
#         <Price>12000</Price>
#         <Square>234</Square>
#     </Ad>
# </Ads>
# """
# ```
# При помощи языка Python необходимо вывести список всех значений тегов в виде `['xjfdge4735202', 'Квартиры', ...]`
# Введите список всех значений тегов приведенного выше XML-документа:

# %%
from bs4 import BeautifulSoup

xml = """
<?xml version="1.0" encoding="UTF-8"?>
<Ads formatVersion="3" target="Avito.ru">
    <Ad>
        <Id>xjfdge4735202</Id>
        <Category>Квартиры</Category>
        <OperationType>Продам</OperationType>
        <DateBegin>2015-11-27</DateBegin>
        <DateEnd>2079-08-28</DateEnd>
        <Description>
            Новая, просторная, светлая и уютная квартира
        </Description>
        <ManagerName>Иван Петров-Водкин</ManagerName>
        <ContactPhone>+7 916 683-78-22</ContactPhone>
        <Images>
            <Image url="http://img.test.ru/8F7B-4A4F3A0F2BA1.jpg" />
        </Images>
        <Rooms>2</Rooms>
        <Square>61</Square>
        <Floor>13</Floor>
        <Floors>16</Floors>
        <HouseType>Деревянный</HouseType>
        <MarketType>Новостройка</MarketType>
    </Ad>
    <Ad>
        <Id>xjfdge4735204</Id>
        <Category>Комнаты</Category>
        <Description>Новая, просторная, светлая и уютная квартира.</Description>
        <Price>102000</Price>
        <Rooms>2</Rooms>
        <Square>61.3</Square>
        <Floor>14</Floor>
        <Floors>16</Floors>
        <HouseType>Деревянный</HouseType>
        <OperationType>Сдам</OperationType>
    </Ad>
    <Ad>
        <Id>xjfdge4735205</Id>
        <Category>Коммерческая недвижимость</Category>
        <OperationType>Сдам</OperationType>
        <Description>Hедвижимость.</Description>
        <Price>12000</Price>
        <Square>234</Square>
    </Ad>
</Ads>
"""

# Создание объекта BeautifulSoup и парсинг XML
soup = BeautifulSoup(xml, features='html.parser')

# Извлечение всех текстовых значений, убирая лишние пробелы
values = [string for string in soup.stripped_strings]

# Печать всех значений тегов
print(values)
# Out:
# ['xjfdge4735202', 'Квартиры', 'Продам', '2015-11-27', '2079-08-28', 'Новая, просторная, светлая и уютная квартира', 'Иван Петров-Водкин', '+7 916 683-78-22', '2', '61', '13', '16', 'Деревянный', 'Новостройка', 'xjfdge4735204', 'Комнаты', 'Новая, просторная, светлая и уютная квартира.', '102000', '2', '61.3', '14', '16', 'Деревянный', 'Сдам', 'xjfdge4735205', 'Коммерческая недвижимость', 'Сдам', 'Hедвижимость.', '12000', '234']

# %% [markdown]
# 3. Дан некий фрагмент XML-документа:
# ```
# xml = """
# <?xml version="1.0" encoding="UTF-8"?>
# <Ads formatVersion="3" target="Avito.ru">
#     <Ad>
#         <Id>xjfdge4735202</Id>
#         <Category>Квартиры</Category>
#         <OperationType>Продам</OperationType>
#         <DateBegin>2015-11-27</DateBegin>
#         <DateEnd>2079-08-28</DateEnd>
#         <Description>Новая, просторная, светлая и уютная квартира </Description>
#         <ManagerName>Иван Петров-Водкин</ManagerName>
#         <ContactPhone>+7 916 683-78-22</ContactPhone>
#         <Images>
#             <Image url="http://img.test.ru/8F7B-4A4F3A0F2BA1.jpg" />
#         </Images>
#         <Rooms>2</Rooms>
#         <Square>61</Square>
#         <Floor>13</Floor>
#         <Floors>16</Floors>
#         <HouseType>Деревянный</HouseType>
#         <MarketType>Новостройка</MarketType>
#     </Ad>
#     <Ad>
#         <Id>xjfdge4735204</Id>
#         <Category>Комнаты</Category>
#         <Description>Новая, просторная, светлая и уютная квартира. </Description>
#         <Price>102000</Price>
#         <Rooms>2</Rooms>
#         <Square>61.3</Square>
#         <Floor>14</Floor>
#         <Floors>16</Floors>
#         <HouseType>Деревянный</HouseType>
#         <OperationType>Сдам</OperationType>
#     </Ad>
#     <Ad>
#         <Id>xjfdge4735205</Id>
#         <Category>Коммерческая недвижимость</Category>
#         <OperationType>Сдам</OperationType>
#         <Description>Hедвижимость.</Description>
#         <Price>12000</Price>
#         <Square>234</Square>
#     </Ad>
# </Ads>
# """
# ```
# При помощи языка Python напишите функцию `add_tag(data,text)`, которая добавляет новый тег `<type>Новое объявление</type>` в конец приведенного выше XML-документа. На вход функция получает объект `data` конструктора `BeautifulSoup` (в нашем случае `data = BeautifulSoup(xml, features='lxml')`') и текст тега `text` (в нашем случае `text = 'Новое объявление'`).
# ```
# from bs4 import BeautifulSoup
# data = BeautifulSoup(xml, features='lxml')
# text = 'Новое объявление'
# def add_tag(data,text):
# #ваш код здесь
# ```

# %%
from bs4 import BeautifulSoup

xml = """
<?xml version="1.0" encoding="UTF-8"?>
<Ads formatVersion="3" target="Avito.ru">
    <Ad>
        <Id>xjfdge4735202</Id>
        <Category>Квартиры</Category>
        <OperationType>Продам</OperationType>
        <DateBegin>2015-11-27</DateBegin>
        <DateEnd>2079-08-28</DateEnd>
        <Description>Новая, просторная, светлая и уютная квартира </Description>
        <ManagerName>Иван Петров-Водкин</ManagerName>
        <ContactPhone>+7 916 683-78-22</ContactPhone>
        <Images>
            <Image url="http://img.test.ru/8F7B-4A4F3A0F2BA1.jpg" />
        </Images>
        <Rooms>2</Rooms>
        <Square>61</Square>
        <Floor>13</Floor>
        <Floors>16</Floors>
        <HouseType>Деревянный</HouseType>
        <MarketType>Новостройка</MarketType>
    </Ad>
    <Ad>
        <Id>xjfdge4735204</Id>
        <Category>Комнаты</Category>
        <Description>Новая, просторная, светлая и уютная квартира. </Description>
        <Price>102000</Price>
        <Rooms>2</Rooms>
        <Square>61.3</Square>
        <Floor>14</Floor>
        <Floors>16</Floors>
        <HouseType>Деревянный</HouseType>
        <OperationType>Сдам</OperationType>
    </Ad>
    <Ad>
        <Id>xjfdge4735205</Id>
        <Category>Коммерческая недвижимость</Category>
        <OperationType>Сдам</OperationType>
        <Description>Hедвижимость.</Description>
        <Price>12000</Price>
        <Square>234</Square>
    </Ad>
</Ads>
"""

data = BeautifulSoup(xml, features='html.parser')
text = 'Новое объявление'

def add_tag(data, text):
    # Найти все элементы <Ad>
    ads = data.find_all('ad')
    
    # Для каждого элемента <Ad> добавляем новый тег <type> с указанным текстом
    for ad in ads:
        new_tag = data.new_tag('type')
        new_tag.string = text
        ad.append(new_tag)
    
    return data

# Применение функции
updated_data = add_tag(data, text)

# Печать обновленного XML-документа с отступами для лучшей читаемости
print(updated_data.prettify())
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <ads formatversion="3" target="Avito.ru">
#  <ad>
#   <id>
#    xjfdge4735202
#   </id>
#   <category>
#    Квартиры
#   </category>
#   <operationtype>
#    Продам
#   </operationtype>
#   <datebegin>
#    2015-11-27
#   </datebegin>
#   <dateend>
#    2079-08-28
#   </dateend>
#   <description>
#    Новая, просторная, светлая и уютная квартира
#   </description>
#   <managername>
#    Иван Петров-Водкин
#   </managername>
#   <contactphone>
#    +7 916 683-78-22
#   </contactphone>
#   <images>
#    <image url="http://img.test.ru/8F7B-4A4F3A0F2BA1.jpg"/>
#   </images>
#   <rooms>
#    2
#   </rooms>
#   <square>
#    61
#   </square>
#   <floor>
#    13
#   </floor>
#   <floors>
#    16
#   </floors>
#   <housetype>
#    Деревянный
#   </housetype>
#   <markettype>
#    Новостройка
#   </markettype>
#   <type>
#    Новое объявление
#   </type>
#  </ad>
#  <ad>
#   <id>
#    xjfdge4735204
#   </id>
#   <category>
#    Комнаты
#   </category>
#   <description>
#    Новая, просторная, светлая и уютная квартира.
#   </description>
#   <price>
#    102000
#   </price>
#   <rooms>
#    2
#   </rooms>
#   <square>
#    61.3
#   </square>
#   <floor>
#    14
#   </floor>
#   <floors>
#    16
#   </floors>
#   <housetype>
#    Деревянный
#   </housetype>
#   <operationtype>
#    Сдам
#   </operationtype>
#   <type>
#    Новое объявление
#   </type>
#  </ad>
#  <ad>
#   <id>
#    xjfdge4735205
#   </id>
#   <category>
#    Коммерческая недвижимость
#   </category>
#   <operationtype>
#    Сдам
#   </operationtype>
#   <description>
#    Hедвижимость.
#   </description>
#   <price>
#    12000
#   </price>
#   <square>
#    234
#   </square>
#   <type>
#    Новое объявление
#   </type>
#  </ad>
# </ads>

# %% [markdown]
# 4. Дан некий фрагмент XML-документа:
# ```
# xml = """
# <?xml version="1.0" encoding="UTF-8"?>
# <Ads formatVersion="3" target="Avito.ru">
#     <Ad>
#         <Id>xjfdge4735202</Id>
#         <Category>Квартиры</Category>
#         <OperationType>Продам</OperationType>
#         <DateBegin>2015-11-27</DateBegin>
#         <DateEnd>2079-08-28</DateEnd>
#         <Description>Новая, просторная, светлая и уютная квартира </Description>
#         <ManagerName>Иван Петров-Водкин</ManagerName>
#         <ContactPhone>+7 916 683-78-22</ContactPhone>
#         <Images>
#             <Image url="http://img.test.ru/8F7B-4A4F3A0F2BA1.jpg" />
#         </Images>
#         <Rooms>2</Rooms>
#         <Square>61</Square>
#         <Floor>13</Floor>
#         <Floors>16</Floors>
#         <HouseType>Деревянный</HouseType>
#         <MarketType>Новостройка</MarketType>
#     </Ad>
#     <Ad>
#         <Id>xjfdge4735204</Id>
#         <Category>Комнаты</Category>
#         <Description>Новая, просторная, светлая и уютная квартира. </Description>
#         <Price>102000</Price>
#         <Rooms>2</Rooms>
#         <Square>61.3</Square>
#         <Floor>14</Floor>
#         <Floors>16</Floors>
#         <HouseType>Деревянный</HouseType>
#         <OperationType>Сдам</OperationType>
#     </Ad>
#     <Ad>
#         <Id>xjfdge4735205</Id>
#         <Category>Коммерческая недвижимость</Category>
#         <OperationType>Сдам</OperationType>
#         <Description>Hедвижимость.</Description>
#         <Price>12000</Price>
#         <Square>234</Square>
#     </Ad>
# </Ads>
# """
# ```
# При помощи языка Python выведите значения тегов, где встречается слово `квартира` (Квартира, квартир и т.д). Для выполнения задания необходимо использовать регулярные выражения.
# ```
# from bs4 import BeautifulSoup
# import re
# data = BeautifulSoup(xml, features='lxml')
# #ваш код здесь
# ```

# %%
from bs4 import BeautifulSoup
import re

xml = """
<?xml version="1.0" encoding="UTF-8"?>
<Ads formatVersion="3" target="Avito.ru">
    <Ad>
        <Id>xjfdge4735202</Id>
        <Category>Квартиры</Category>
        <OperationType>Продам</OperationType>
        <DateBegin>2015-11-27</DateBegin>
        <DateEnd>2079-08-28</DateEnd>
        <Description>Новая, просторная, светлая и уютная квартира </Description>
        <ManagerName>Иван Петров-Водкин</ManagerName>
        <ContactPhone>+7 916 683-78-22</ContactPhone>
        <Images>
            <Image url="http://img.test.ru/8F7B-4A4F3A0F2BA1.jpg" />
        </Images>
        <Rooms>2</Rooms>
        <Square>61</Square>
        <Floor>13</Floor>
        <Floors>16</Floors>
        <HouseType>Деревянный</HouseType>
        <MarketType>Новостройка</MarketType>
    </Ad>
    <Ad>
        <Id>xjfdge4735204</Id>
        <Category>Комнаты</Category>
        <Description>Новая, просторная, светлая и уютная квартира. </Description>
        <Price>102000</Price>
        <Rooms>2</Rooms>
        <Square>61.3</Square>
        <Floor>14</Floor>
        <Floors>16</Floors>
        <HouseType>Деревянный</HouseType>
        <OperationType>Сдам</OperationType>
    </Ad>
    <Ad>
        <Id>xjfdge4735205</Id>
        <Category>Коммерческая недвижимость</Category>
        <OperationType>Сдам</OperationType>
        <Description>Hедвижимость.</Description>
        <Price>12000</Price>
        <Square>234</Square>
    </Ad>
</Ads>
"""

# Создание объекта BeautifulSoup и парсинг XML
data = BeautifulSoup(xml, features='html.parser')

# Регулярное выражение для поиска слова "квартира" в разных формах
for tag in data.find_all(string = re.compile('\wвартир\w*')):
  print(tag)
# Out:
# Квартиры
# Новая, просторная, светлая и уютная квартира
# Новая, просторная, светлая и уютная квартира.
# <>:53: SyntaxWarning: invalid escape sequence '\w'
# <>:53: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\stalk\AppData\Local\Temp\ipykernel_7548\1621471729.py:53: SyntaxWarning: invalid escape sequence '\w'
#   for tag in data.find_all(string = re.compile('\wвартир\w*')):
