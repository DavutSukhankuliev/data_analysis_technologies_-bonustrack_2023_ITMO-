# %%
# Среди студентов проводился опрос о том, какие цифровые навыки будут полезны им в дальнейшей профессиональной деятельности. Была возможность выбора из нескольких предложенных вариантов, никто из студентов не выбрал больше, чем 9 пунктов. 
# 
# В следующем файле содержатся данные опроса студентов. Структура файла такова: каждая строка отвечает выбору студента, а столбцы с наименованиями Choice_1, Choice_2, ..., Choice_9 — отранжированному по важности выбранному списку навыков. Каждая ячейка содержит наименование выбранного навыка.
# 
# Ваша задача — на основе предложенных данных визуализировать результаты голосования.

import pandas as pd
import openpyxl

all_choices = pd.read_excel('Ind test 1.2.1 Task 1 - RAW data var732742.xlsx')

all_choices
# Out:
#                 Choice_1                          Choice_2  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3    Визуализация данных                 Машинное обучение
# 4               Big Data  Методы искусственного интеллекта
# ..                   ...                               ...
# 595  Электронные таблицы               Визуализация данных
# 596  Визуализация данных  Методы искусственного интеллекта
# 597  Визуализация данных                    Анализ текстов
# 598             Big Data                    Анализ текстов
# 599           Статистика               Визуализация данных
#
#                              Choice_3                          Choice_4  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                 Визуализация данных                               NaN
# ..                                ...                               ...
# 595                 Машинное обучение                               NaN
# 596                            Python                 Машинное обучение
# 597  Методы искусственного интеллекта                            Python
# 598             Обработка изображений  Методы искусственного интеллекта
# 599                               NaN                               NaN
#
#               Choice_5  Choice_6           Choice_7             Choice_8  \
# 0                  NaN       NaN                NaN                  NaN
# 1                  NaN       NaN                NaN                  NaN
# 2                  NaN       NaN                NaN                  NaN
# 3                  NaN       NaN                NaN                  NaN
# 4                  NaN       NaN                NaN                  NaN
# ..                 ...       ...                ...                  ...
# 595                NaN       NaN                NaN                  NaN
# 596         Статистика       NaN                NaN                  NaN
# 597  Машинное обучение  Big Data                NaN                  NaN
# 598         Статистика    Python  Машинное обучение  Визуализация данных
# 599                NaN       NaN                NaN                  NaN
#
#                 Choice_9
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ..                   ...
# 595                  NaN
# 596                  NaN
# 597                  NaN
# 598  Электронные таблицы
# 599                  NaN
#
# [600 rows x 9 columns]

# %%
# Пункт 1. Постройте столбчатую диаграмму по столбцу Choice_1 (столбец самого востребованного навыка).

to_plot = pd.DataFrame(all_choices['Choice_1'].value_counts())
to_plot
# Out:
#                                   count
# Choice_1
# Статистика                           78
# Визуализация данных                  66
# Big Data                             56
# Python                               52
# Методы искусственного интеллекта     50
# Анализ текстов                       46
# Электронные таблицы                  43
# Обработка изображений                38
# Машинное обучение                    36
# Ничего из перечисленного             14

# %%
to_plot.columns = ['Amount']
to_plot = to_plot.sort_index()
to_plot
# Out:
#                                   Amount
# Choice_1
# Big Data                              56
# Python                                52
# Анализ текстов                        46
# Визуализация данных                   66
# Машинное обучение                     36
# Методы искусственного интеллекта      50
# Ничего из перечисленного              14
# Обработка изображений                 38
# Статистика                            78
# Электронные таблицы                   43

# %%
import matplotlib.pyplot as plt

plt.bar(to_plot.index, to_plot['Amount'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
# Пункт 2. Постройте круговую диаграммму по всем выбранным навыкам.

full_to_plot = pd.DataFrame(pd.DataFrame(all_choices.values.reshape(-1))[0].value_counts())
full_to_plot.columns = ['Amount']
full_to_plot = full_to_plot.sort_index()
full_to_plot
# Out:
#                                   Amount
# 0
# Big Data                             217
# Python                               221
# Анализ текстов                       189
# Визуализация данных                  293
# Машинное обучение                    209
# Методы искусственного интеллекта     219
# Ничего из перечисленного              17
# Обработка изображений                178
# Статистика                           268
# Электронные таблицы                  222

# %%
plt.pie(full_to_plot['Amount'], labels = full_to_plot.index, startangle=168, autopct='%1.2f%%', counterclock=False)
plt.show()
